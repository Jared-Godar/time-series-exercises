# %% [markdown]
# # Curriculum Acquire code

# %% [markdown]
# ## Making HTTP Requests
#
# - The way we interact with web sites and web servers (including RESTful JSON APIs) is through HTTP **requests** and **responses**.
#
# - We can use the `requests` library to make http requests. This is somewhat the same as visiting a url in your browser, except that we can interact with the responses programatically in python.

# %%
import requests

# %% [markdown]
# We will use the `get` function from `requests` and pass it a url:

# %%
response = requests.get('http://request-inspector.glitch.me/')
response
# Out:
# <Response [200]>

# %% [markdown]
# <p>We get back a python object that represents an HTTP response.</p>
# <p>The response object has several interesting properties:</p>
# <ul>
# <li><code>.ok</code>: a boolean that indicates that the response was successful (the server sent back a 200 response code)</li>
# <li><code>.status_code</code>: a number indicating the HTTP response status code </li>
# <li><code>.text</code>: the raw response text</li>
# </ul>

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"method":"GET","query":{},"body":{}}'

# %% [markdown]
# <p>In this case, we see a string that contains HTML. HTML is what makes up web pages that are intended for humans to read. If you go to http://example.com, you'll see what the HTML in the above response looks like when rendered. Some other endpoints on the internet return JSON, which is usually intended to be worked with programatically.</p>

# %% [markdown]
# <h2 id="example-json-api">Example JSON API</h2>
# <p>For an example of a JSON api, we'll interact with the <a href="https://aphorisms.glitch.me/">a quote generator</a>.</p>

# %%
url = 'https://swapi.dev/api/people/5'
response = requests.get(url)
print(response.text)
# Out:
# {"name":"Leia Organa","height":"150","mass":"49","hair_color":"brown","skin_color":"light","eye_color":"brown","birth_year":"19BBY","gender":"female","homeworld":"https://swapi.dev/api/planets/2/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":["https://swapi.dev/api/vehicles/30/"],"starships":[],"created":"2014-12-10T15:20:09.791000Z","edited":"2014-12-20T21:17:50.315000Z","url":"https://swapi.dev/api/people/5/"}

# %% [markdown]
# <p>Here we see that the repsonse we got back contains a JSON object (we could also verify this by visiting the URL in a web browser).</p>
# <p>Since the response is JSON, we can use the <code>.json</code> method on the response object to get a data structure we can work with:</p>

# %%
data = response.json()
print(type(data))
data
# Out:
# <class 'dict'>
# {'name': 'Leia Organa',
#  'height': '150',
#  'mass': '49',
#  'hair_color': 'brown',
#  'skin_color': 'light',
#  'eye_color': 'brown',
#  'birth_year': '19BBY',
#  'gender': 'female',
#  'homeworld': 'https://swapi.dev/api/planets/2/',
#  'films': ['https://swapi.dev/api/films/1/',
#   'https://swapi.dev/api/films/2/',
#   'https://swapi.dev/api/films/3/',
#   'https://swapi.dev/api/films/6/'],
#  'species': [],
#  'vehicles': ['https://swapi.dev/api/vehicles/30/'],
#  'starships': [],
#  'created': '2014-12-10T15:20:09.791000Z',
#  'edited': '2014-12-20T21:17:50.315000Z',
#  'url': 'https://swapi.dev/api/people/5/'}

# %% [markdown]
# <p>Now we have a dictionary that we can work with.</p>
# <p>Let's now take a look at another api. We'll start by looking at just the base URL:  </p>

# %%
base_url = 'https://python.zgulde.net'
print(requests.get(base_url).text)
# Out:
# {"api":"/api/v1","help":"/documentation"}

# %%
{"api":"/api/v1","help":"/documentation"}
# Out:
# {'api': '/api/v1', 'help': '/documentation'}

# %% [markdown]
# <p>This API provides some documentation, so let's make a request so that we can take a look at it.</p>

# %%
response = requests.get(base_url + '/documentation')
print(response.json()['payload'])
# Out:
# The API accepts GET requests for all endpoints, where endpoints are prefixed
# with
#
#     /api/{version}
#
# Where version is "v1"
#
# Valid endpoints:
#
# - /stores[/{store_id}]
# - /items[/{item_id}]
# - /sales[/{sale_id}]
#
# All endpoints accept a `page` parameter that can be used to navigate through
# the results.

# %% [markdown]
# <p>Based on this, let's take a look at the items. We'll make our request, and explore the shape of the response that we get back.</p>

# %%
response = requests.get('https://python.zgulde.net/api/v1/items')

data = response.json()
data.keys()
# Out:
# dict_keys(['payload', 'status'])

# %%
data['payload'].keys()
# Out:
# dict_keys(['items', 'max_page', 'next_page', 'page', 'previous_page'])

# %%
print('max_page: %s' % data['payload']['max_page'])
print('next_page: %s' % data['payload']['next_page'])
# Out:
# max_page: 3
# next_page: /api/v1/items?page=2

# %% [markdown]
# <p>Here the response has some built-in properties that tell us how to get to subsequent pages.</p>
# <p>Once we've drilled down into the data structure, we'll find that the entire response is a sort of wrapper around the <code>items</code> property:</p>

# %%
data['payload']['items'][:2]
# Out:
# [{'item_brand': 'Riceland',
#   'item_id': 1,
#   'item_name': 'Riceland American Jazmine Rice',
#   'item_price': 0.84,
#   'item_upc12': '35200264013',
#   'item_upc14': '35200264013'},
#  {'item_brand': 'Caress',
#   'item_id': 2,
#   'item_name': 'Caress Velvet Bliss Ultra Silkening Beauty Bar - 6 Ct',
#   'item_price': 6.44,
#   'item_upc12': '11111065925',
#   'item_upc14': '11111065925'}]

# %% [markdown]
# <p>We can turn this data into a pandas dataframe:</p>

# %%
import pandas as pd

df = pd.DataFrame(data['payload']['items'])
df.head()
# Out:
#        item_brand  item_id                                          item_name  \
# 0        Riceland        1                     Riceland American Jazmine Rice
# 1          Caress        2  Caress Velvet Bliss Ultra Silkening Beauty Bar...
# 2     Earths Best        3  Earths Best Organic Fruit Yogurt Smoothie Mixe...
# 3      Boars Head        4   Boars Head Sliced White American Cheese - 120 Ct
# 4  Back To Nature        5  Back To Nature Gluten Free White Cheddar Rice ...
#
#    item_price    item_upc12    item_upc14
# 0        0.84   35200264013   35200264013
# 1        6.44   11111065925   11111065925
# 2        2.43   23923330139   23923330139
# 3        3.14  208528800007  208528800007
# 4        2.61  759283100036  759283100036

# %% [markdown]
# <p>Now that we've gotten the data from the first page, we can extract the data from the next page (as indicated by the API's response), and add it onto our dataframe:</p>

# %%
response = requests.get(base_url + data['payload']['next_page'])
data = response.json()

print('max_page: %s' % data['payload']['max_page'])
print('next_page: %s' % data['payload']['next_page'])

df = pd.concat([df, pd.DataFrame(data['payload']['items'])]).reset_index()
# Out:
# max_page: 3
# next_page: /api/v1/items?page=3

# %% [markdown]
# <p>We'll repeat the process one more time:</p>

# %%
response = requests.get(base_url + data['payload']['next_page'])
data = response.json()

print('max_page: %s' % data['payload']['max_page'])
print('next_page: %s' % data['payload']['next_page'])

df = pd.concat([df, pd.DataFrame(data['payload']['items'])]).reset_index()
# Out:
# max_page: 3
# next_page: None

# %% [markdown]
# <p>Now that the API says that the <code>next_page</code> is None, we'll stop making requests, and assume that we have all of the <code>items</code> data.</p>

# %%
df.shape
# Out:
# (50, 8)

# %%
df
# Out:
#     level_0  index              item_brand  item_id  \
# 0         0    0.0                Riceland        1
# 1         1    1.0                  Caress        2
# 2         2    2.0             Earths Best        3
# 3         3    3.0              Boars Head        4
# 4         4    4.0          Back To Nature        5
# 5         5    5.0            Sally Hansen        6
# 6         6    6.0      Twinings Of London        7
# 7         7    7.0           Lea & Perrins        8
# 8         8    8.0            Van De Kamps        9
# 9         9    9.0                   Ahold       10
# 10       10   10.0              Honest Tea       11
# 11       11   11.0                 Mueller       12
# 12       12   12.0   Garnier Nutritioniste       13
# 13       13   13.0                 Pamprin       14
# 14       14   14.0                   Suave       15
# 15       15   15.0              Burts Bees       16
# 16       16   16.0                   Ducal       17
# 17       17   17.0                  Scotch       18
# 18       18   18.0                 Careone       19
# 19       19   19.0            Usda Produce       20
# 20       20    0.0            Doctors Best       21
# 21       21    1.0           Betty Crocker       22
# 22       22    2.0                   Reese       23
# 23       23    3.0            Smart Living       24
# 24       24    4.0                    Hood       25
# 25       25    5.0               Triaminic       26
# 26       26    6.0                  Morton       27
# 27       27    7.0            Usda Produce       28
# 28       28    8.0                   Heinz       29
# 29       29    9.0                 Petmate       30
# 30       30   10.0        Zhenas Gypsy Tea       31
# 31       31   11.0                Barefoot       32
# 32       32   12.0         The First Years       33
# 33       33   13.0                   Halls       34
# 34       34   14.0             Natures Way       35
# 35       35   15.0  Deerfields Gluten Free       36
# 36       36   16.0                  Nakano       37
# 37       37   17.0        Sundown Naturals       38
# 38       38   18.0                Munchies       39
# 39       39   19.0                    Amys       40
# 40        0    NaN             P.f. Changs       41
# 41        1    NaN      Moms Best Naturals       42
# 42        2    NaN                 Ferrara       43
# 43        3    NaN                  Elmers       44
# 44        4    NaN                Kelloggs       45
# 45        5    NaN              Mama Marys       46
# 46        6    NaN              Bear Naked       47
# 47        7    NaN                    Dove       48
# 48        8    NaN                Easy-off       49
# 49        9    NaN                  Choice       50
#
#                                             item_name  item_price  \
# 0                      Riceland American Jazmine Rice        0.84
# 1   Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# 2   Earths Best Organic Fruit Yogurt Smoothie Mixe...        2.43
# 3    Boars Head Sliced White American Cheese - 120 Ct        3.14
# 4   Back To Nature Gluten Free White Cheddar Rice ...        2.61
# 5   Sally Hansen Nail Color Magnetic 903 Silver El...        6.93
# 6   Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
# 7   Lea & Perrins Marinade In-a-bag Cracked Pepper...        1.68
# 8          Van De Kamps Fillets Beer Battered - 10 Ct        1.79
# 9                                 Ahold Cocoa Almonds        3.17
# 10                         Honest Tea Peach White Tea        3.93
# 11  Mueller Sport Care Basic Support Level Medium ...        8.40
# 12  Garnier Nutritioniste Moisture Rescue Fresh Cl...        6.47
# 13  Pamprin Maximum Strength Multi-symptom Menstru...        7.54
# 14  Suave Naturals Moisturizing Body Wash Creamy T...        9.11
# 15      Burts Bees Daily Moisturizing Cream Sensitive        5.17
# 16                            Ducal Refried Red Beans        1.16
# 17    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 18                     Careone Family Comb Set - 8 Ct        0.74
# 19                                        Plums Black        5.62
# 20  Doctors Best Best Curcumin C3 Complex 1000mg T...        8.09
# 21  Betty Crocker Twin Pack Real Potatoes Scallope...        7.31
# 22     Reese Mandarin Oranges Segments In Light Syrup        1.78
# 23                Smart Living Charcoal Lighter Fluid        5.34
# 24         Hood Latte Iced Coffee Drink Vanilla Latte        2.43
# 25  Triaminic Syrup Night Time Cold & Cough Grape 4oz        0.98
# 26                          Morton Kosher Salt Coarse        6.01
# 27                                              Guava        7.52
# 28                        Heinz Tomato Ketchup - 2 Ct        8.65
# 29  Petmate Booda Bones Steak Bacon & Chicken Flav...        8.39
# 30  Zhenas Gypsy Tea Herbal Red Tea Sachets Fire L...        4.21
# 31                         Barefoot Pinot Grigio  187        0.68
# 32  Tomy The First Years Gumdrop Orthodontic Pacif...        6.52
# 33  Halls Menthol Cough Suppresant/oral Anesthetic...        4.17
# 34                     Natures Way Forskohlii - 60 Ct        5.19
# 35           Rice Bran Gluten Free Dinner Rolls Plain        7.95
# 36              Nakano Seasoned Rice Vinegar Original        9.59
# 37  Sundown Naturals Essential Electrolytes Tropic...        3.45
# 38  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 39               Amys Light & Lean Spaghetti Italiano        0.60
# 40  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 41  Moms Best Naturals Cereal Toasted Cinnamon Squ...        2.97
# 42                              Ferrara Vanilla Syrup        8.40
# 43                Elmers Board Mate Dual Tip Glue Pen        7.06
# 44                Kelloggs Disney Pixar Cars 2 Cereal        4.40
# 45                                        Pizza Sauce        4.65
# 46  Bear Naked Fit Almond Crisp 100 Percent Natura...        7.38
# 47  Dove Men + Care Antiperspirant Deodorant Cool ...        3.72
# 48                  Easy-off Oven Cleaner Lemon Scent        9.54
# 49  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#       item_upc12    item_upc14
# 0    35200264013   35200264013
# 1    11111065925   11111065925
# 2    23923330139   23923330139
# 3   208528800007  208528800007
# 4   759283100036  759283100036
# 5    74170388732   74170388732
# 6    70177154004   70177154004
# 7    51600080015   51600080015
# 8    19600923015   19600923015
# 9   688267141676  688267141676
# 10  657622604842  657622604842
# 11   74676640211   74676640211
# 12  603084234561  603084234561
# 13   41167300121   41167300121
# 14   79400847201   79400847201
# 15  792850014008  792850014008
# 16   88313590791   88313590791
# 17   21200725340   21200725340
# 18   41520035646   41520035646
# 19  204040000000  204040000000
# 20  753950001954  753950001954
# 21   16000288829   16000288829
# 22   70670009658   70670009658
# 23  688267084225  688267084225
# 24   44100117428   44100117428
# 25  300436344045  300436344045
# 26   24600017008   24600017008
# 27  719175900007  719175900007
# 28   13000001038   13000001038
# 29  723503568678  723503568678
# 30  652790100226  652790100226
# 31    8500004528    8500004528
# 32   71463060078   71463060078
# 33  312546628694  312546628694
# 34   33674100066   33674100066
# 35  610358991525  610358991525
# 36   73575295003   73575295003
# 37   30768540548   30768540548
# 38   28400029254   28400029254
# 39   42272008063   42272008063
# 40   31000670016   31000670016
# 41  883978129115  883978129115
# 42   71403000379   71403000379
# 43   26000001403   26000001403
# 44   38000542237   38000542237
# 45   35457770664   35457770664
# 46  884623708976  884623708976
# 47   79400271631   79400271631
# 48   62338879772   62338879772
# 49   47445919221   47445919221

# %% [markdown]
# <h2 id="further-reading">Further Reading</h2>
# <ul>
# <li><a href="https://www.dataquest.io/blog/python-api-tutorial/">Using APIs in Python</a></li>
# <li><a href="https://www.smashingmagazine.com/2018/01/understanding-using-rest-api/">Understand and using REST APIs</a></li>
# </ul>

# %% [markdown]
# ---

# %% [markdown]
# ## Dataquest API Tutorial

# %% [markdown]
# <p>In this Python API tutorial, we’ll learn how to retrieve data for data science projects. There are millions of APIs online which provide access to data. Websites like <a href="https://www.reddit.com/dev/api/" style="outline: none;">Reddit</a>, <a href="https://developer.twitter.com/en/docs.html" style="outline: none;">Twitter</a>, and <a href="https://developers.facebook.com/" style="outline: none;">Facebook</a> all offer certain data through their APIs.</p>
# <p>To use an API, you make a request to a remote web server, and retrieve the data you need.</p>
# <p>But why use an API instead of a static CSV dataset you can download from the web? APIs are useful in the following cases:</p>

# %% [markdown]
# <ul>
# <li><strong>The data is changing quickly</strong>. An example of this is stock price data. It doesn’t really make sense to regenerate a dataset and download it every minute — this will take a lot of bandwidth, and be pretty slow.</li>
# <li><strong>You want a small piece of a much larger set of data</strong>. Reddit comments are one example. What if you want to just pull your own comments on Reddit? It doesn’t make much sense to download the entire Reddit database, then filter just your own comments.</li>
# <li><strong>There is repeated computation involved</strong>. Spotify has an API that can tell you the genre of a piece of music. You could theoretically create your own classifier, and use it to compute music categories, but you’ll never have as much data as Spotify does.</li>
# </ul>
# <p>In cases like the ones above, an API is the right solution. In this blog post, we’ll be querying a simple API to retrieve data about the <a href="https://en.wikipedia.org/wiki/International_Space_Station" style="outline: none;">International Space Station</a> (ISS).</p>
# <h2>About this Python API Tutorial</h2>
# <p>This tutorial is based on part of our interactive course on APIs and Webscraping in Python, which you can <a href="https://www.dataquest.io/course/apis-and-scraping/" style="outline: none;">start for free</a>.</p>
# <p>For this tutorial, we assume that you know some of the fundamentals of working with data in Python. If you don’t, you might like to try our <a href="https://www.dataquest.io/course/python-for-data-science-fundamentals/" style="outline: none;">free Python Fundamentals course</a>.</p>
# <p>If you’re looking for something more advanced, check out our <a href="https://www.dataquest.io/blog/last-fm-api-python/" style="outline: none;">Intermediate API tutorial</a>.</p>
# <h2>What is an API?</h2>
# <p>An API, or Application Programming Interface, is a server that you can use to retrieve and send data to using code. APIs are most commonly used to retrieve data, and that will be the focus of this beginner tutorial.</p>
# <p>When we want to receive data from an API, we need to make a <strong>request</strong>. Requests are used all over the web. For instance, when you visited this blog post, your web browser made a request to the Dataquest web server, which responded with the content of this web page.</p>
# <p><span></span></p>

# %% [markdown]
# <h2>Making API Requests in Python</h2>
# <p>In order to work with APIs in Python, we need tools that will make those requests. In Python, the most common library for making requests and working with APIs is the <a href="https://2.python-requests.org/en/master/" style="outline: none;"><strong>requests</strong> library</a>. The requests library isn’t part of the standard Python library, so you’ll need to install it to get started.</p>

# %%
import requests

# %% [markdown]
# <h2>Making Our First API Request</h2>
# <p>There are many different types of requests. The most commonly used one, a <strong>GET</strong> request, is used to retrieve data. Because we’ll just be working with retrieving data, our focus will be on making ‘get’ requests.</p>
# <p>When we make a request, the response from the API comes with a <strong>response code</strong> which tells us whether our request was successful. Response codes are important because they immediately tell us if something went wrong.</p>

# %%
response=requests.get('https://api.open-notify.org/this-api-doesnt-exist')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fcd88962370>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='api.open-notify.org', port=443): Max retries exceeded with url: /this-api-doesnt-exist (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fcd88962370>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /var/folders/9y/17ptyrds267724n2_7s7hx340000gn/T/ipykernel_13234/3948440958.py in <module>
# ----> 1 response=requests.get('https://api.open-notify.org/this-api-doesnt-exist')
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.open-notify.org', port=443): Max retries exceeded with url: /this-api-doesnt-exist (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fcd88962370>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
print(response.status_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9y/17ptyrds267724n2_7s7hx340000gn/T/ipykernel_13234/2193030176.py in <module>
# ----> 1 print(response.status_code)
#
# NameError: name 'response' is not defined

# %% [markdown]
# <p><img src="https://web.archive.org/web/20200107014409im_/https://www.dataquest.io/wp-content/uploads/2019/09/api-request.svg" data-src="https://www.dataquest.io/wp-content/uploads/2019/09/api-request.svg" alt="" />To make a ‘GET’ request, we’ll use the <a href="https://2.python-requests.org/en/master/user/quickstart/#make-a-request" style="outline: none;"><code>requests.get()</code> function</a>, which requires one argument — the URL we want to make the request to. We’ll start by making a request to an API endpoint that doesn’t exist, so we can see what that response code looks like.</p>
# <pre><code class="language-python">response = requests.get("https://api.open-notify.org/this-api-doesnt-exist")</code></pre>
# <p>The <code>get()</code> function returns a <a href="https://2.python-requests.org/en/master/user/advanced/#request-and-response-objects" style="outline: none;"><code>response</code> object</a>. We can use the <code><a href="https://2.python-requests.org/en/master/user/quickstart/#response-status-codes" style="outline: none;">response.status_code</a></code> attribute to receive the status code for our request:</p>
# <pre><code class="language-python">print(response.status_code)</code></pre>
# <pre><code class="language-markup">404</code></pre>
# <p>The ‘404’ status code might be familiar to you — it’s the status code that a server returns if it can’t find the file we requested. In this case, we asked for <code>this-api-doesnt-exist</code> which (surprise, surprise) didn’t exist!</p>
# <p>Let’s learn a little more about common status codes.</p>

# %%
response = requests.get("http://api.open-notify.org/astros.json")
print(response.status_code)
# Out:
# 200

# %%
import json

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
jprint(response.json())
# Out:
# {
#     "message": "success",
#     "number": 10,
#     "people": [
#         {
#             "craft": "ISS",
#             "name": "Mark Vande Hei"
#         },
#         {
#             "craft": "ISS",
#             "name": "Pyotr Dubrov"
#         },
#         {
#             "craft": "ISS",
#             "name": "Anton Shkaplerov"
#         },
#         {
#             "craft": "Shenzhou 13",
#             "name": "Zhai Zhigang"
#         },
#         {
#             "craft": "Shenzhou 13",
#             "name": "Wang Yaping"
#         },
#         {
#             "craft": "Shenzhou 13",
#             "name": "Ye Guangfu"
#         },
#         {
#             "craft": "ISS",
#             "name": "Raja Chari"
#         },
#         {
#             "craft": "ISS",
#             "name": "Tom Marshburn"
#         },
#         {
#             "craft": "ISS",
#             "name": "Kayla Barron"
#         },
#         {
#             "craft": "ISS",
#             "name": "Matthias Maurer"
#         }
#     ]
# }

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['people', 'message', 'number'])

# %%
data
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Mark Vande Hei'},
#   {'craft': 'ISS', 'name': 'Pyotr Dubrov'},
#   {'craft': 'ISS', 'name': 'Anton Shkaplerov'},
#   {'craft': 'Shenzhou 13', 'name': 'Zhai Zhigang'},
#   {'craft': 'Shenzhou 13', 'name': 'Wang Yaping'},
#   {'craft': 'Shenzhou 13', 'name': 'Ye Guangfu'},
#   {'craft': 'ISS', 'name': 'Raja Chari'},
#   {'craft': 'ISS', 'name': 'Tom Marshburn'},
#   {'craft': 'ISS', 'name': 'Kayla Barron'},
#   {'craft': 'ISS', 'name': 'Matthias Maurer'}],
#  'message': 'success',
#  'number': 10}

# %%
astro_df = pd.DataFrame(data['people'])
astro_df.head()
# Out:
#          craft              name
# 0          ISS    Mark Vande Hei
# 1          ISS      Pyotr Dubrov
# 2          ISS  Anton Shkaplerov
# 3  Shenzhou 13      Zhai Zhigang
# 4  Shenzhou 13       Wang Yaping

# %% [markdown]
# ---

# %% [markdown]
# <h2 id="what-is-a-rest-api">What Is A REST API</h2>
#
# <p>Let’s say you’re trying to find videos about Batman on Youtube. You open up Youtube, type &ldquo;Batman&rdquo; into a search field, hit enter, and you see a list of videos about Batman. A REST API works in a similar way. You search for something, and you get a list of results back from the service you’re requesting from.</p>
#
# <p>An <strong>API</strong> is an application programming interface. It is a set of rules that allow programs to talk to each other. The developer creates the API on the server and allows the client to talk to it.</p>
#
# <p><strong>REST</strong> determines how the API looks like. It stands for &ldquo;Representational State Transfer&rdquo;. It is a set of rules that developers follow when they create their API. One of these rules states that you should be able to get a piece of data (called a resource) when you link to a specific URL.</p>
#
# <p>Each URL is called a <strong>request</strong> while the data sent back to you is called a <strong>response</strong>.</p>

# %% [markdown]
# <p>It’s important to know that a request is made up of four things:</p>
#
# <ol>
# <li>The endpoint</li>
# <li>The method</li>
# <li>The headers</li>
# <li>The data (or body)</li>
# </ol>

# %% [markdown]
# <p><strong>The endpoint</strong> (or route) is the url you request for. It follows this structure:</p>
#
# <pre><code class="language-bash">root-endpoint/<path>?<query-params>
# </code></pre>
#
# <p>The <strong>root-endpoint</strong> is the starting point of the API you’re requesting from. The root-endpoint of <a href="https://developer.github.com/v3/">Github’s API</a> is <code>https://api.github.com</code> while the root-endpoint <a href="https://dev.twitter.com/rest/reference">Twitter’s API</a> is <code>https://api.twitter.com</code>.</p>
#
# <p>The <strong>path</strong> determines the resource you’re requesting for. Think of it like an automatic answering machine that asks you to press 1 for a service, press 2 for another service, 3 for yet another service and so on.</p>

# %% [markdown]
# <p>You can access paths just like you can link to parts of a website. For example, to get a list of all posts tagged under &ldquo;JavaScript&rdquo; on Smashing Magazine, you navigate to <code>https://www.smashingmagazine.com/tag/javascript/</code>. <code>https://www.smashingmagazine.com/</code> is the root-endpoint and <code>/tag/javascript</code> is the path.</p>
#
# <p>To understand what paths are available to you, you need to look through the API documentation.
# For example, let’s say you want to get a list of repositories by a certain user through Github’s API. The <a href="https://developer.github.com/v3/repos/#list-user-repositories">docs</a> tells you to use the the following path to do so:</p>
#
# <pre><code class="language-bash">/users/:username/repos
# </code></pre>
#
# <p>Any colons (<code>:</code>) on a path denotes a variable. You should replace these values with actual values of when you send your request. In this case, you should replace <code>:username</code> with the actual username of the user you’re searching for. If I’m searching for my Github account, I’ll replace <code>:username</code> with <code>zellwk</code>.</p>
#
# <p>The endpoint to get a list of my repos on Github is this:</p>
#
# <pre><code class="language-bash">https://api.github.com/users/zellwk/repos</code></pre>

# %% [markdown]
# <p>The final part of an endpoint is <strong>query parameters</strong>. Technically, query parameters are not part of the REST architecture, but you’ll see lots of APIs use them. So, to help you completely understand how to read and use API’s we’re also going to talk about them.
# Query parameters give you the option to modify your request with key-value pairs. They always begin with a question mark (<code>?</code>). Each parameter pair is then separated with an ampersand (<code>&amp;</code>), like this:</p>
#
# <div class="break-out"><pre><code class="language-bash">?query1=value1&query2=value2
# </code></pre></div>
#
# <p>When you try to get a list of a user’s repositories on Github, you add three possible parameters to your request to modify the results given to you:</p>

# %%
repos = requests.get('https://api.github.com/users/jared-godar/repos?sort=pushed')

# %%
repos
# Out:
# <Response [200]>

# %%
repos=repos.json()

# %%
print(type(repos))
# Out:
# <class 'list'>

# %%
repos
# Out:
# [{'id': 446510779,
#   'node_id': 'R_kgDOGp02uw',
#   'name': 'time-series-exercises',
#   'full_name': 'Jared-Godar/time-series-exercises',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/time-series-exercises',
#   'description': 'Repository for Codeup time series exercises',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/time-series-exercises/deployments',
#   'created_at': '2022-01-10T17:01:49Z',
#   'updated_at': '2022-01-10T17:19:38Z',
#   'pushed_at': '2022-01-10T17:19:35Z',
#   'git_url': 'git://github.com/Jared-Godar/time-series-exercises.git',
#   'ssh_url': 'git@github.com:Jared-Godar/time-series-exercises.git',
#   'clone_url': 'https://github.com/Jared-Godar/time-series-exercises.git',
#   'svn_url': 'https://github.com/Jared-Godar/time-series-exercises',
#   'homepage': None,
#   'size': 11,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 434725691,
#   'node_id': 'R_kgDOGeljOw',
#   'name': 'regression-project',
#   'full_name': 'Jared-Godar/regression-project',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/regression-project',
#   'description': 'Repostory for Codeup Zillo regression project',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/regression-project',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/regression-project/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/regression-project/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/regression-project/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/regression-project/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/regression-project/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/regression-project/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/regression-project/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/regression-project/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/regression-project/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/regression-project/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/regression-project/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/regression-project/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/regression-project/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/regression-project/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/regression-project/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/regression-project/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/regression-project/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/regression-project/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/regression-project/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/regression-project/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/regression-project/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/regression-project/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/regression-project/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/regression-project/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/regression-project/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/regression-project/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/regression-project/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/regression-project/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/regression-project/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/regression-project/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/regression-project/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/regression-project/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/regression-project/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/regression-project/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/regression-project/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/regression-project/deployments',
#   'created_at': '2021-12-03T20:30:27Z',
#   'updated_at': '2022-01-06T18:00:01Z',
#   'pushed_at': '2022-01-06T17:59:58Z',
#   'git_url': 'git://github.com/Jared-Godar/regression-project.git',
#   'ssh_url': 'git@github.com:Jared-Godar/regression-project.git',
#   'clone_url': 'https://github.com/Jared-Godar/regression-project.git',
#   'svn_url': 'https://github.com/Jared-Godar/regression-project',
#   'homepage': None,
#   'size': 3043,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 439079672,
#   'node_id': 'R_kgDOGivS-A',
#   'name': 'clustering-project',
#   'full_name': 'Jared-Godar/clustering-project',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/clustering-project',
#   'description': 'Codeup Zillow Error Estimate modeling projext',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/clustering-project',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/clustering-project/deployments',
#   'created_at': '2021-12-16T17:50:36Z',
#   'updated_at': '2022-01-05T15:08:48Z',
#   'pushed_at': '2022-01-05T15:08:46Z',
#   'git_url': 'git://github.com/Jared-Godar/clustering-project.git',
#   'ssh_url': 'git@github.com:Jared-Godar/clustering-project.git',
#   'clone_url': 'https://github.com/Jared-Godar/clustering-project.git',
#   'svn_url': 'https://github.com/Jared-Godar/clustering-project',
#   'homepage': None,
#   'size': 8664,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 426362537,
#   'node_id': 'R_kgDOGWnGqQ',
#   'name': 'classification-exercises',
#   'full_name': 'Jared-Godar/classification-exercises',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/classification-exercises',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/classification-exercises',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/classification-exercises/deployments',
#   'created_at': '2021-11-09T19:39:10Z',
#   'updated_at': '2022-01-05T15:03:04Z',
#   'pushed_at': '2022-01-05T15:03:00Z',
#   'git_url': 'git://github.com/Jared-Godar/classification-exercises.git',
#   'ssh_url': 'git@github.com:Jared-Godar/classification-exercises.git',
#   'clone_url': 'https://github.com/Jared-Godar/classification-exercises.git',
#   'svn_url': 'https://github.com/Jared-Godar/classification-exercises',
#   'homepage': None,
#   'size': 11539,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 438377119,
#   'node_id': 'R_kgDOGiEanw',
#   'name': 'clustering-exercises',
#   'full_name': 'Jared-Godar/clustering-exercises',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/clustering-exercises',
#   'description': 'Repository for Codeup clustering exercises',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/clustering-exercises/deployments',
#   'created_at': '2021-12-14T19:34:54Z',
#   'updated_at': '2022-01-04T20:16:53Z',
#   'pushed_at': '2022-01-04T20:16:51Z',
#   'git_url': 'git://github.com/Jared-Godar/clustering-exercises.git',
#   'ssh_url': 'git@github.com:Jared-Godar/clustering-exercises.git',
#   'clone_url': 'https://github.com/Jared-Godar/clustering-exercises.git',
#   'svn_url': 'https://github.com/Jared-Godar/clustering-exercises',
#   'homepage': None,
#   'size': 11424,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 406860394,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MDY4NjAzOTQ=',
#   'name': 'codeup_notes',
#   'full_name': 'Jared-Godar/codeup_notes',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/codeup_notes',
#   'description': 'Notes for Codeup',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/codeup_notes',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/codeup_notes/deployments',
#   'created_at': '2021-09-15T17:11:49Z',
#   'updated_at': '2022-01-03T15:12:18Z',
#   'pushed_at': '2022-01-03T15:12:15Z',
#   'git_url': 'git://github.com/Jared-Godar/codeup_notes.git',
#   'ssh_url': 'git@github.com:Jared-Godar/codeup_notes.git',
#   'clone_url': 'https://github.com/Jared-Godar/codeup_notes.git',
#   'svn_url': 'https://github.com/Jared-Godar/codeup_notes',
#   'homepage': None,
#   'size': 49574,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'main'},
#  {'id': 441191957,
#   'node_id': 'R_kgDOGkwOFQ',
#   'name': 'sql-zoo-exercises',
#   'full_name': 'Jared-Godar/sql-zoo-exercises',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/sql-zoo-exercises',
#   'description': 'Repository for exercises from https://sqlzoo.net/wiki/SQL_Tutorial',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/sql-zoo-exercises/deployments',
#   'created_at': '2021-12-23T13:39:34Z',
#   'updated_at': '2021-12-24T19:26:07Z',
#   'pushed_at': '2021-12-24T19:26:05Z',
#   'git_url': 'git://github.com/Jared-Godar/sql-zoo-exercises.git',
#   'ssh_url': 'git@github.com:Jared-Godar/sql-zoo-exercises.git',
#   'clone_url': 'https://github.com/Jared-Godar/sql-zoo-exercises.git',
#   'svn_url': 'https://github.com/Jared-Godar/sql-zoo-exercises',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 441192966,
#   'node_id': 'R_kgDOGkwSBg',
#   'name': 'hackerrank-sql',
#   'full_name': 'Jared-Godar/hackerrank-sql',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/hackerrank-sql',
#   'description': 'Repo for SQL exercises from  https://www.hackerrank.com/domains/sql?filters%5Bskills%5D%5B%5D=SQL%20%28Basic%29',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/hackerrank-sql/deployments',
#   'created_at': '2021-12-23T13:43:23Z',
#   'updated_at': '2021-12-24T19:25:33Z',
#   'pushed_at': '2021-12-24T19:25:30Z',
#   'git_url': 'git://github.com/Jared-Godar/hackerrank-sql.git',
#   'ssh_url': 'git@github.com:Jared-Godar/hackerrank-sql.git',
#   'clone_url': 'https://github.com/Jared-Godar/hackerrank-sql.git',
#   'svn_url': 'https://github.com/Jared-Godar/hackerrank-sql',
#   'homepage': None,
#   'size': 2,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 430115784,
#   'node_id': 'R_kgDOGaMLyA',
#   'name': 'pmi-acp',
#   'full_name': 'Jared-Godar/pmi-acp',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
# ...
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/test2',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/test2',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/test2/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/test2/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/test2/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/test2/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/test2/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/test2/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/test2/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/test2/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/test2/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/test2/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/test2/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/test2/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/test2/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/test2/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/test2/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/test2/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/test2/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/test2/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/test2/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/test2/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/test2/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/test2/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/test2/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/test2/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/test2/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/test2/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/test2/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/test2/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/test2/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/test2/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/test2/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/test2/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/test2/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/test2/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/test2/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/test2/deployments',
#   'created_at': '2021-09-16T15:56:47Z',
#   'updated_at': '2021-09-16T15:56:47Z',
#   'pushed_at': '2021-09-16T15:56:48Z',
#   'git_url': 'git://github.com/Jared-Godar/test2.git',
#   'ssh_url': 'git@github.com:Jared-Godar/test2.git',
#   'clone_url': 'https://github.com/Jared-Godar/test2.git',
#   'svn_url': 'https://github.com/Jared-Godar/test2',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 407205137,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MDcyMDUxMzc=',
#   'name': 'git_practice',
#   'full_name': 'Jared-Godar/git_practice',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/git_practice',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/git_practice',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/git_practice/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/git_practice/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/git_practice/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/git_practice/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/git_practice/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/git_practice/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/git_practice/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/git_practice/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/git_practice/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/git_practice/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/git_practice/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/git_practice/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/git_practice/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/git_practice/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/git_practice/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/git_practice/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/git_practice/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/git_practice/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/git_practice/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/git_practice/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/git_practice/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/git_practice/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/git_practice/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/git_practice/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/git_practice/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/git_practice/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/git_practice/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/git_practice/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/git_practice/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/git_practice/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/git_practice/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/git_practice/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/git_practice/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/git_practice/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/git_practice/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/git_practice/deployments',
#   'created_at': '2021-09-16T14:52:19Z',
#   'updated_at': '2021-09-16T15:44:55Z',
#   'pushed_at': '2021-09-16T15:44:52Z',
#   'git_url': 'git://github.com/Jared-Godar/git_practice.git',
#   'ssh_url': 'git@github.com:Jared-Godar/git_practice.git',
#   'clone_url': 'https://github.com/Jared-Godar/git_practice.git',
#   'svn_url': 'https://github.com/Jared-Godar/git_practice',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 407194831,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MDcxOTQ4MzE=',
#   'name': 'my-new-project',
#   'full_name': 'Jared-Godar/my-new-project',
#   'private': False,
#   'owner': {'login': 'Jared-Godar',
#    'id': 16855088,
#    'node_id': 'MDQ6VXNlcjE2ODU1MDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16855088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jared-Godar',
#    'html_url': 'https://github.com/Jared-Godar',
#    'followers_url': 'https://api.github.com/users/Jared-Godar/followers',
#    'following_url': 'https://api.github.com/users/Jared-Godar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Jared-Godar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Jared-Godar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Jared-Godar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Jared-Godar/orgs',
#    'repos_url': 'https://api.github.com/users/Jared-Godar/repos',
#    'events_url': 'https://api.github.com/users/Jared-Godar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Jared-Godar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Jared-Godar/my-new-project',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Jared-Godar/my-new-project',
#   'forks_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/forks',
#   'keys_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/teams',
#   'hooks_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/events',
#   'assignees_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/tags',
#   'blobs_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/languages',
#   'stargazers_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/subscription',
#   'commits_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/merges',
#   'archive_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/downloads',
#   'issues_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Jared-Godar/my-new-project/deployments',
#   'created_at': '2021-09-16T14:23:55Z',
#   'updated_at': '2021-09-16T14:28:10Z',
#   'pushed_at': '2021-09-16T14:28:06Z',
#   'git_url': 'git://github.com/Jared-Godar/my-new-project.git',
#   'ssh_url': 'git@github.com:Jared-Godar/my-new-project.git',
#   'clone_url': 'https://github.com/Jared-Godar/my-new-project.git',
#   'svn_url': 'https://github.com/Jared-Godar/my-new-project',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'}]

# %%
repos[0].keys()
# Out:
# dict_keys(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count', 'mirror_url', 'archived', 'disabled', 'open_issues_count', 'license', 'allow_forking', 'is_template', 'topics', 'visibility', 'forks', 'open_issues', 'watchers', 'default_branch'])
